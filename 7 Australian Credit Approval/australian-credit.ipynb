# %%
columns = [
    "A1","A2","A3","A4","A5","A6","A7",
    "A8","A9","A10","A11","A12","A13","A14","Class"
]

# %%
import pandas as pd

df = pd.read_csv("australian.dat", header=None, names=columns, sep=" ", skipinitialspace=True)

print(df.head())

# %%
print(df.isna().sum())

# %%
df = df.apply(pd.to_numeric, errors="coerce")

# %%
print(df.info())
print(df.describe(include="all"))
