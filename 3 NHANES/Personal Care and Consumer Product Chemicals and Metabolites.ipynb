# %%
import pandas as pd

# Cargar archivo XPT
df = pd.read_sas("dataset.xpt", format="xport")

# %%
# Ver nombres de columnas
print(df.columns)
# Out:
# Index(['SEQN', 'WTSB2YR', 'URXBP3', 'URDBP3LC', 'URXBPH', 'URDBPHLC', 'URXBPF',
#        'URDBPFLC', 'URXBPS', 'URDBPSLC', 'URXTLC', 'URDTLCLC', 'URXTRS',
#        'URDTRSLC', 'URXBUP', 'URDBUPLC', 'URXEPB', 'URDEPBLC', 'URXMPB',
#        'URDMPBLC', 'URXPPB', 'URDPPBLC', 'URX14D', 'URD14DLC', 'URXDCB',
#        'URDDCBLC'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2986 entries, 0 to 2985
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      2986 non-null   float64
#  1   WTSB2YR   2986 non-null   float64
#  2   URXBP3    2759 non-null   float64
#  3   URDBP3LC  2759 non-null   float64
#  4   URXBPH    2758 non-null   float64
#  5   URDBPHLC  2758 non-null   float64
#  6   URXBPF    2757 non-null   float64
#  7   URDBPFLC  2757 non-null   float64
#  8   URXBPS    2756 non-null   float64
#  9   URDBPSLC  2756 non-null   float64
#  10  URXTLC    2761 non-null   float64
#  11  URDTLCLC  2761 non-null   float64
#  12  URXTRS    2740 non-null   float64
#  13  URDTRSLC  2740 non-null   float64
#  14  URXBUP    2761 non-null   float64
#  15  URDBUPLC  2761 non-null   float64
#  16  URXEPB    2759 non-null   float64
#  17  URDEPBLC  2759 non-null   float64
#  18  URXMPB    2743 non-null   float64
#  19  URDMPBLC  2743 non-null   float64
#  20  URXPPB    2760 non-null   float64
#  21  URDPPBLC  2760 non-null   float64
#  22  URX14D    2759 non-null   float64
#  23  URD14DLC  2759 non-null   float64
#  24  URXDCB    2760 non-null   float64
#  25  URDDCBLC  2760 non-null   float64
# dtypes: float64(26)
# memory usage: 606.7 KB

# %%
# columnas de concentraciones
cols_values = [col for col in df.columns if col.startswith("URX")]

# columnas de flags (LOD)
cols_flags = [col for col in df.columns if col.endswith("LC")]

# %%
df[cols_flags].value_counts()
# Out:
# URDBP3LC      URDBPHLC      URDBPFLC      URDBPSLC      URXTLC  URDTLCLC      URDTRSLC      URDBUPLC      URDEPBLC      URDMPBLC      URDPPBLC      URD14DLC      URDDCBLC
# 5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  0.07    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79    190
#                             1.000000e+00  5.397605e-79  0.07    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79    183
#                             5.397605e-79  5.397605e-79  0.07    1.000000e+00  1.000000e+00  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79    131
#                                                                               5.397605e-79  1.000000e+00  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79    121
#                             1.000000e+00  5.397605e-79  0.07    1.000000e+00  5.397605e-79  1.000000e+00  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79    114
#                                                                                                                                                                                  ...
#                             5.397605e-79  5.397605e-79  0.07    1.000000e+00  5.397605e-79  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  5.397605e-79  5.397605e-79      1
#               1.000000e+00  1.000000e+00  5.397605e-79  0.20    5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79      1
#               5.397605e-79  5.397605e-79  5.397605e-79  2.20    5.397605e-79  5.397605e-79  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79      1
#                             1.000000e+00  1.000000e+00  0.50    5.397605e-79  5.397605e-79  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79      1
#               1.000000e+00  1.000000e+00  1.000000e+00  0.07    1.000000e+00  5.397605e-79  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  5.397605e-79  1.000000e+00      1
# Name: count, Length: 593, dtype: int64

# %%
import numpy as np

# convertir valores bajo LOD a NaN (o a LOD/√2 dependiendo del análisis)
for col in cols_values:
    flag_col = col.replace("URX", "URD") + "LC"
    if flag_col in df.columns:
        df.loc[df[flag_col] == 1, col] = np.nan

# %%
df[cols_values].describe()
# Out:
#              URXBP3       URXBPH       URXBPF       URXBPS      URXTLC  \
# count   2712.000000  2372.000000  1441.000000  2441.000000  882.000000
# mean     181.353540     1.819393     4.623664     2.320934    3.834014
# std     1197.714191     9.351129    25.887575    29.070773   13.048369
# min        0.400000     0.200000     0.200000     0.100000    0.100000
# 25%        4.100000     0.500000     0.300000     0.300000    0.100000
# 50%       11.200000     0.900000     0.600000     0.600000    0.200000
# 75%       39.100000     1.600000     1.600000     1.300000    0.800000
# max    30900.000000   408.000000   727.000000  1220.000000  175.000000
#
#             URXTRS      URXBUP       URXEPB        URXMPB       URXPPB  \
# count  1153.000000  457.000000  1154.000000   2698.000000  2629.000000
# mean    108.282134    2.809628    47.087955    193.024240    35.936402
# std     260.563500    8.533964   173.826538    819.573109   178.669316
# min       1.700000    0.100000     1.000000      1.000000     0.100000
# 25%       2.800000    0.200000     1.800000      7.200000     0.700000
# 50%       6.200000    0.300000     4.600000     25.300000     2.700000
# 75%      79.900000    1.600000    20.475000    115.750000    17.200000
# max    2820.000000   79.100000  2290.000000  21100.000000  6750.000000
#
#              URX14D       URXDCB
# count   2701.000000  2453.000000
# mean     130.846501     4.041256
# std      958.048029    24.473717
# min        0.100000     0.100000
# 25%        0.800000     0.300000
# 50%        2.100000     0.500000
# 75%       10.000000     1.000000
# max    23500.000000   575.000000

# %%
df.columns()
